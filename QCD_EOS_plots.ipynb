# %%
from ms_hm.QCD_EOS import *
import numpy as np
qcd = QCD_EOS()

# %%
qcd.P_plot()

# %%
qcd.dPdrho_plot()

# %%
qcd.MH_plot()

# %%
rhos = np.logspace(0,26,100)
Ts = qcd.TofRho(rhos)
plt.loglog(rhos, Ts)
